# %%
import pandas as pd

# %%
filename = 'Dataset of Diabetes .csv'

# %%
data = pd.read_csv(filename)

# %%
data
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# 1    23.0     N
# ...

# %%
data.head()
# Out:
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
data.tail()
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 995  30.0     Y
# 996  37.2    Y
# 997  27.4    Y
# 998  40.5    Y
# 999  33.0    Y

# %%
data.sample(5)
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG   HDL  LDL  VLDL  \
# 810  304      34558      F   60  4.50  57   14.4  6.80  2.9  1.00  0.9   1.6
# 344  297      34346      M   54  4.20  48    6.5  2.40  1.0  1.00  0.9   0.7
# 112  393      47496      M   49  5.00  74    6.2  2.00  0.8  0.60  1.0   0.4
# 732  632      56743      M   55  4.16  30    6.8  6.12  3.5  1.03  3.6  24.5
# 220  351      34266      M   47  5.80  62    4.0  7.00  2.8  0.90  4.9   1.3
#
#        BMI CLASS
# 810  26.00     Y
# 344  33.00     Y
# 112  25.00     P
# 732  27.33     Y
# 220  24.00     Y

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   object
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  CLASS      1000 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 109.5+ KB

# %%
hdl_mean = data['HDL'].mean()
hdl_mean
# Out:
# np.float64(1.20475)

# %%
hdl_median = data['HDL'].median()
hdl_median
# Out:
# 1.1

# %%
hdl_mode = data['HDL'].mode()
hdl_mode
# Out:
# 0    1.1
# Name: HDL, dtype: float64

# %%
data2 = pd.read_csv('SalariesInSanFranciscoDataSet.csv')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1244\419436165.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2 = pd.read_csv('SalariesInSanFranciscoDataSet.csv')

# %%
data2.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
data2.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
#TODO: treat missing values for the following features

'''
BasePay                605
Benefits             36159
Notes               148654
Status              110535
'''
# Out:
# '\nBasePay                605\nBenefits             36159\nNotes               148654\nStatus              110535\n'

# %%
# missing data
# skewed
# outliers
# correlations
# normalized
# scale
# scatter matrix

# %%
#MISSING DATA

data.fillna()
data.fillna(method='pad') #filling null values with the previous ones
data.fillna(method='bfill') #Filling null value with the next ones
data.replace(to_replace= np.nan, value= -99)
data.interpolate(method= 'linear', limit_direction = 'forward') #Using interpolate() function to 
data.dropna() #Dropping rows with at least 1 null value
data.dropna(how='all') #Dropping rows if all values in that row are missing

# %%
''linear interpolation for time series data. for example measuring the height of a boy every month''

# %%
import numpy as np

dt = pd.DataFrame({
    "A": [1,2,np.nan, np.nan],
    "B": [4,5,np.nan,7]
})

# %%
dt
# Out:
#      A    B
# 0  1.0  4.0
# 1  2.0  5.0
# 2  NaN  NaN
# 3  NaN  7.0

# %%
dt = dt.interpolate(method='linear', limit_direction='forward')

# %%
dt
# Out:
#      A    B
# 0  1.0  4.0
# 1  2.0  5.0
# 2  2.0  6.0
# 3  2.0  7.0

# %%
# TYPES OF CATEGORICAL DATA

# ORDINAL 
# NOMINAL
