# %%
import pandas as pd

# %%
df = pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.T.duplicated()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
X = df.iloc[:,:-1]
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
Y = df.iloc[:,-1]
Y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %% [markdown]
# #Univariate Selection

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
# Apply SelectKBest Algorithm

rank = SelectKBest(score_func=chi2, k=4)
ordered_features = rank.fit(X, Y)
ordered_features
# Out:
# SelectKBest(k=4, score_func=<function chi2 at 0x000002199149E5C0>)

# %%
ordered_features.scores_
# Out:
# array([ 111.51969064, 1411.88704064,   17.60537322,   53.10803984,
#        2175.56527292,  127.66934333,    5.39268155,  181.30368904])

# %%
dfscores = pd.DataFrame(ordered_features.scores_)
dfscores
# Out:
#              0
# 0   111.519691
# 1  1411.887041
# 2    17.605373
# 3    53.108040
# 4  2175.565273
# 5   127.669343
# 6     5.392682
# 7   181.303689

# %%
dfcolumns = pd.DataFrame(X.columns)
dfcolumns
# Out:
#                           0
# 0               Pregnancies
# 1                   Glucose
# 2             BloodPressure
# 3             SkinThickness
# 4                   Insulin
# 5                       BMI
# 6  DiabetesPedigreeFunction
# 7                       Age

# %%
features_rank = pd.concat([dfcolumns,dfscores],axis=1)
features_rank
# Out:
#                           0            0
# 0               Pregnancies   111.519691
# 1                   Glucose  1411.887041
# 2             BloodPressure    17.605373
# 3             SkinThickness    53.108040
# 4                   Insulin  2175.565273
# 5                       BMI   127.669343
# 6  DiabetesPedigreeFunction     5.392682
# 7                       Age   181.303689

# %%
features_rank.columns = ['Features', 'Scores']
features_rank
# Out:
#                    Features       Scores
# 0               Pregnancies   111.519691
# 1                   Glucose  1411.887041
# 2             BloodPressure    17.605373
# 3             SkinThickness    53.108040
# 4                   Insulin  2175.565273
# 5                       BMI   127.669343
# 6  DiabetesPedigreeFunction     5.392682
# 7                       Age   181.303689

# %%
features_rank.nlargest(5, 'Scores')
# Out:
#       Features       Scores
# 4      Insulin  2175.565273
# 1      Glucose  1411.887041
# 7          Age   181.303689
# 5          BMI   127.669343
# 0  Pregnancies   111.519691

# %% [markdown]
# ##Feature Importance
#
# This techique gives you a score for each feature of your data, the higher the score, the more relevant it is

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,Y)
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.11008105 0.23621478 0.09974286 0.07955476 0.07369498 0.13977472
#  0.11823677 0.14270009]

# %%
ranked_features = pd.Series(model.feature_importances_, index=X.columns)
ranked_features
# Out:
# Pregnancies                 0.110081
# Glucose                     0.236215
# BloodPressure               0.099743
# SkinThickness               0.079555
# Insulin                     0.073695
# BMI                         0.139775
# DiabetesPedigreeFunction    0.118237
# Age                         0.142700
# dtype: float64

# %%
ranked_features.nlargest(10).plot.bar()
# Out:
# <Axes: >
